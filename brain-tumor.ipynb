# %%
import os
os.environ["TF_CUDNN_USE_AUTOTUNE"] = "0"
os.environ["TF_XLA_FLAGS"] = "--tf_xla_enable_xla_devices=false"

import tensorflow as tf

tf.config.optimizer.set_jit(False)
tf.config.set_soft_device_placement(True)

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    tf.config.experimental.set_memory_growth(gpus[0], True)
# Out:
# 2026-04-24 18:23:50.442345: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777035230.456640   27451 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777035230.460566   27451 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777035230.473092   27451 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777035230.473118   27451 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777035230.473120   27451 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777035230.473121   27451 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-24 18:23:50.477014: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# import tensorflow as tf

# print("TensorFlow Version:", tf.__version__)

# gpus = tf.config.list_physical_devices('GPU')

# if gpus:
#     print("\n✅ GPU is available")
#     for i, gpu in enumerate(gpus):
#         print(f"GPU {i}: {gpu}")
# else:
#     print("\n❌ No GPU found")

# %%
# ! chmod 600 ~/.kaggle/kaggle.json

# %%
# ! kaggle datasets download awsaf49/brats20-dataset-training-validation

# %%
# ! unzip brats20-dataset-training-validation.zip

# %%
import os
import cv2
import random
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps
import nibabel as nib
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
# import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
from tensorflow.keras.layers import Rescaling, Normalization

# %%
import os
os.environ["TF_XLA_FLAGS"] = "--tf_xla_enable_xla_devices=false"

# %%
TRAIN_DATASET_PATH = "BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/"

# %%
# import os

# old_name = TRAIN_DATASET_PATH + "BraTS20_Training_355/W39_1998.09.19_Segm.nii"
# new_name = TRAIN_DATASET_PATH + "BraTS20_Training_355/BraTS20_Training_355_seg.nii"

# if os.path.exists(old_name):
#     os.rename(old_name, new_name)
#     print("Renamed successfully")
# else:
#     print("Already renamed or file not found")

# %%
# load .nii file
test_image_flair = nib.load(
    TRAIN_DATASET_PATH + "BraTS20_Training_355/BraTS20_Training_355_flair.nii"
).get_fdata()

print("Shape:", test_image_flair.shape)
print("Dtype:", test_image_flair.dtype)
# Out:
# Shape: (240, 240, 155)
# Dtype: float64

# %%
# load .nii file as a numpy array
test_image_flair = nib.load(TRAIN_DATASET_PATH + "BraTS20_Training_355/BraTS20_Training_355_flair.nii").get_fdata()
print("Shape: ", test_image_flair.shape)
print("Dtype: ", test_image_flair.dtype)
# Out:
# Shape:  (240, 240, 155)
# Dtype:  float64

# %%
print("Min: ", test_image_flair.min())
print("Max: ", test_image_flair.max())
# Out:
# Min:  0.0
# Max:  1854.603271484375

# %%
scaler = MinMaxScaler()

# %%
# Scale the test_image_flair array and then reshape it back to its original dimensions.
# This ensures the data is normalized/standardized for model input without altering its spatial structure.
test_image_flair = scaler.fit_transform(test_image_flair.reshape(-1, test_image_flair.shape[-1])).reshape(test_image_flair.shape)

# %%
print("Min: ", test_image_flair.min())
print("Max: ", test_image_flair.max())
# Out:
# Min:  0.0
# Max:  1.0

# %%
# rescaling t1
test_image_t1 = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t1.nii').get_fdata()
test_image_t1 = scaler.fit_transform(test_image_t1.reshape(-1, test_image_t1.shape[-1])).reshape(test_image_t1.shape)

# rescaling t1ce
test_image_t1ce = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t1ce.nii').get_fdata()
test_image_t1ce = scaler.fit_transform(test_image_t1ce.reshape(-1, test_image_t1ce.shape[-1])).reshape(test_image_t1ce.shape)

# rescaling t2
test_image_t2 = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_t2.nii').get_fdata()
test_image_t2 = scaler.fit_transform(test_image_t2.reshape(-1, test_image_t2.shape[-1])).reshape(test_image_t2.shape)

# we will not rescale the mask
test_image_seg = nib.load(TRAIN_DATASET_PATH + 'BraTS20_Training_355/BraTS20_Training_355_seg.nii').get_fdata()

# %%
slice = 95

print("Slice Number: " + str(slice))

plt.figure(figsize=(12, 8))

# T1
plt.subplot(2, 3, 1)
plt.imshow(test_image_t1[:,:,slice], cmap='gray')
plt.title('T1')

# T1ce
plt.subplot(2, 3, 2)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1ce')

# T2
plt.subplot(2, 3, 3)
plt.imshow(test_image_t2[:,:,slice], cmap='gray')
plt.title('T2')

# Flair
plt.subplot(2, 3, 4)
plt.imshow(test_image_flair[:,:,slice], cmap='gray')
plt.title('FLAIR')

# Mask
plt.subplot(2, 3, 5)
plt.imshow(test_image_seg[:,:,slice])
plt.title('Mask')
plt.show()
# Out:
# Slice Number: 95

# %%
# Modality shape
print("Modality: ", test_image_t1.shape)

# Segmentation shape
print("Segmentation: ", test_image_seg.shape)
# Out:
# Modality:  (240, 240, 155)
# Segmentation:  (240, 240, 155)

# %%
slice = 95

print("Slice number: " + str(slice))

plt.figure(figsize=(12, 8))

# Apply a 90° rotation with an automatic resizing, otherwise the display is less obvious to analyze
# T1 - Transverse View
plt.subplot(1, 3, 1)
plt.imshow(test_image_t1ce[:,:,slice], cmap='gray')
plt.title('T1 - Transverse View')

# T1 - Frontal View
plt.subplot(1, 3, 2)
plt.imshow(rotate(test_image_t1ce[:,slice,:], 90, resize=True), cmap='gray')
plt.title('T1 - Frontal View')

# T1 - Sagittal View
plt.subplot(1, 3, 3)
plt.imshow(rotate(test_image_t1ce[slice,:,:], 90, resize=True), cmap='gray')
plt.title('T1 - Sagittal View')
plt.show()
# Out:
# Slice number: 95

# %%
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)

# montage allows us to concatenate multiple images of the same size horizontally and vertically
plt.imshow(rotate(montage(test_image_t1ce[:,:,:]), 90, resize=True), cmap ='gray');

# %%
# Skip 50:-50 slices since there is not much to see
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)
plt.imshow(rotate(montage(test_image_t1ce[50:-50,:,:]), 90, resize=True), cmap ='gray');

# %%
# Skip 50:-50 slices since there is not much to see
plt.figure(figsize=(10, 10))
plt.subplot(1, 1, 1)
plt.imshow(rotate(montage(test_image_seg[50:-50,:,:]), 90, resize=True), cmap ='gray');

# %%
# Plotting the segmantation
cmap = matplotlib.colors.ListedColormap(['#440054', '#3b528b', '#18b880', '#e6d74f'])
norm = matplotlib.colors.BoundaryNorm([-0.5, 0.5, 1.5, 2.5, 3.5], cmap.N)

# plotting the 95th slice
plt.imshow(test_image_seg[:,:,95], cmap=cmap, norm=norm)
plt.colorbar()
plt.show()

# %%
# Isolation of class 0
seg_0 = test_image_seg.copy()
seg_0[seg_0 != 0] = np.nan

# Isolation of class 1
seg_1 = test_image_seg.copy()
seg_1[seg_1 != 1] = np.nan

# Isolation of class 2
seg_2 = test_image_seg.copy()
seg_2[seg_2 != 2] = np.nan

# Isolation of class 4
seg_4 = test_image_seg.copy()
seg_4[seg_4 != 4] = np.nan

# Define legend
class_names = ['class 0', 'class 1', 'class 2', 'class 4']
legend = [plt.Rectangle((0, 0), 1, 1, color=cmap(i), label=class_names[i]) for i in range(len(class_names))]

fig, ax = plt.subplots(1, 5, figsize=(20, 20))

ax[0].imshow(test_image_seg[:,:, slice], cmap=cmap, norm=norm)
ax[0].set_title('Original Segmentation')
ax[0].legend(handles=legend, loc='lower left')

ax[1].imshow(seg_0[:,:, slice], cmap=cmap, norm=norm)
ax[1].set_title('Not Tumor (class 0)')

ax[2].imshow(seg_1[:,:, slice], cmap=cmap, norm=norm)
ax[2].set_title('Non-Enhancing Tumor (class 1)')

ax[3].imshow(seg_2[:,:, slice], cmap=cmap, norm=norm)
ax[3].set_title('Edema (class 2)')

ax[4].imshow(seg_4[:,:, slice], cmap=cmap, norm=norm)
ax[4].set_title('Enhancing Tumor (class 4)')

plt.show()

# %%
# lists of directories with studies
train_and_val_directories = [f.path for f in os.scandir(TRAIN_DATASET_PATH) if f.is_dir()]

def pathListIntoIds(dirList):
    x = []
    for i in range(0,len(dirList)):
        x.append(dirList[i][dirList[i].rfind('/')+1:])
    return x

train_and_test_ids = pathListIntoIds(train_and_val_directories);

train_test_ids, val_ids = train_test_split(train_and_test_ids,test_size=0.2)
train_ids, test_ids = train_test_split(train_test_ids,test_size=0.15)

# %%
# Print data distribution (Train: 68%, Test: 12%, Val: 20%)
print(f"Train length: {len(train_ids)}")
print(f"Validation length: {len(val_ids)}")
print(f"Test length: {len(test_ids)}")
# Out:
# Train length: 250
# Validation length: 74
# Test length: 45

# %%
plt.bar(["Train","Valid","Test"],
        [len(train_ids), len(val_ids), len(test_ids)],
        align='center',
        color=[ 'green','red', 'blue'],
        label=["Train", "Valid", "Test"]
       )

plt.legend()

plt.ylabel('Number of Images')
plt.title('Data Distribution')

plt.show()

# %%
# Define seg-areas
SEGMENT_CLASSES = {
    0 : 'NOT tumor',
    1 : 'NECROTIC/CORE', # or NON-ENHANCING tumor CORE
    2 : 'EDEMA',
    3 : 'ENHANCING' # original 4 -> converted into 3
}

# Select Slices and Image Size
VOLUME_SLICES = 40
VOLUME_START_AT = 50
IMG_SIZE = 128

# %%
class DataGenerator(keras.utils.Sequence):
    'Generates data for Keras'
    def __init__(self, list_IDs, dim=(IMG_SIZE,IMG_SIZE), batch_size = 1, n_channels = 2, shuffle=True):
        'Initialization'
        self.dim = dim
        self.batch_size = batch_size
        self.list_IDs = list_IDs
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        'Denotes the number of batches per epoch'
        return int(np.floor(len(self.list_IDs) / self.batch_size))

    def __getitem__(self, index):
        'Generate one batch of data'
        # Generate indexes of the batch
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]

        # Find list of IDs
        Batch_ids = [self.list_IDs[k] for k in indexes]

        # Generate data
        X, y = self.__data_generation(Batch_ids)

        return X, y

    def on_epoch_end(self):
        'Updates indexes after each epoch'
        self.indexes = np.arange(len(self.list_IDs))
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def __data_generation(self, Batch_ids):
        'Generates data containing batch_size samples' # X : (n_samples, *dim, n_channels)
        # Initialization
        X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
        y = np.zeros((self.batch_size*VOLUME_SLICES, 240, 240))
        Y = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, 4))


        # Generate data
        for c, i in enumerate(Batch_ids):
            case_path = os.path.join(TRAIN_DATASET_PATH, i)

            data_path = os.path.join(case_path, f'{i}_flair.nii');
            flair = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_t1ce.nii');
            t1ce = nib.load(data_path).get_fdata()

            data_path = os.path.join(case_path, f'{i}_seg.nii');
            seg = nib.load(data_path).get_fdata()

            for j in range(VOLUME_SLICES):
                 X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
                 X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

                 y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];

        # Generate masks
        y[y==4] = 3;
        mask = tf.one_hot(y, 4);
        Y = tf.image.resize(mask, (IMG_SIZE, IMG_SIZE));
        return X/np.max(X), Y

training_generator = DataGenerator(train_ids)
valid_generator = DataGenerator(val_ids)
test_generator = DataGenerator(test_ids)

# %%
# Define a function to display one slice and its segmentation
def display_slice_and_segmentation(flair, t1ce, segmentation):
    fig, axes = plt.subplots(1, 3, figsize=(10, 5))

    axes[0].imshow(flair, cmap='gray')
    axes[0].set_title('Flair')
    axes[0].axis('off')

    axes[1].imshow(t1ce, cmap='gray')
    axes[1].set_title('T1CE')
    axes[1].axis('off')

    axes[2].imshow(segmentation) # Displaying segmentation
    axes[2].set_title('Segmentation')
    axes[2].axis('off')

    plt.tight_layout()
    plt.show()


# Retrieve the batch from the training generator
X_batch, Y_batch = training_generator[8]

# Extract Flair, T1CE, and segmentation from the batch
flair_batch = X_batch[:, :, :, 0]
t1ce_batch = X_batch[:, :, :, 1]
segmentation_batch = np.argmax(Y_batch, axis=-1)  # Convert one-hot encoded to categorical

# Extract the 50th slice from Flair, T1CE, and segmentation
slice_index = 30  # Indexing starts from 0
slice_flair = flair_batch[slice_index]
slice_t1ce = t1ce_batch[slice_index]
slice_segmentation = segmentation_batch[slice_index]

# Display the 50th slice and its segmentation
display_slice_and_segmentation(slice_flair, slice_t1ce, slice_segmentation)
# Out:
# I0000 00:00:1777035238.893081   27451 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5468 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
import tensorflow as tf

# dice loss as defined above for 4 classes
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = tf.reshape(y_true[:,:,:,i], [-1])
        y_pred_f = tf.reshape(y_pred[:,:,:,i], [-1])

        intersection = tf.reduce_sum(y_true_f * y_pred_f)

        loss = ((2. * intersection + smooth) / (
            tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth
        ))

        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss

    total_loss = total_loss / class_num
    return total_loss

# %%
import tensorflow as tf

# Necrotic (class 1)
def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    y_true_c = y_true[:,:,:,1]
    y_pred_c = y_pred[:,:,:,1]

    intersection = tf.reduce_sum(tf.abs(y_true_c * y_pred_c))
    
    return (2. * intersection) / (
        tf.reduce_sum(tf.square(y_true_c)) + 
        tf.reduce_sum(tf.square(y_pred_c)) + 
        epsilon
    )


# Edema (class 2)
def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    y_true_c = y_true[:,:,:,2]
    y_pred_c = y_pred[:,:,:,2]

    intersection = tf.reduce_sum(tf.abs(y_true_c * y_pred_c))
    
    return (2. * intersection) / (
        tf.reduce_sum(tf.square(y_true_c)) + 
        tf.reduce_sum(tf.square(y_pred_c)) + 
        epsilon
    )


# Enhancing tumor (class 3)
def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    y_true_c = y_true[:,:,:,3]
    y_pred_c = y_pred[:,:,:,3]

    intersection = tf.reduce_sum(tf.abs(y_true_c * y_pred_c))
    
    return (2. * intersection) / (
        tf.reduce_sum(tf.square(y_true_c)) + 
        tf.reduce_sum(tf.square(y_pred_c)) + 
        epsilon
    )

# %%
import tensorflow as tf

# Computing Precision
def precision(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    predicted_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    return precision


# Computing Sensitivity (Recall)
def sensitivity(y_true, y_pred):
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    possible_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true, 0, 1)))
    return true_positives / (possible_positives + tf.keras.backend.epsilon())


# Computing Specificity
def specificity(y_true, y_pred):
    true_negatives = tf.reduce_sum(tf.round(tf.clip_by_value((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = tf.reduce_sum(tf.round(tf.clip_by_value(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + tf.keras.backend.epsilon())

# %%
def build_unet(inputs, ker_init, dropout):
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(inputs)
    conv1 = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv1)

    pool = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool)
    conv = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    pool1 = MaxPooling2D(pool_size=(2, 2))(conv)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv2)

    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv3)


    pool4 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(pool4)
    conv5 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv5)
    drop5 = Dropout(dropout)(conv5)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(drop5))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv9)

    up = Conv2D(32, 2, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(UpSampling2D(size = (2,2))(conv9))
    merge = concatenate([conv1,up], axis = 3)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(merge)
    conv = Conv2D(32, 3, activation = 'relu', padding = 'same', kernel_initializer = ker_init)(conv)

    conv10 = Conv2D(4, (1,1), activation = 'softmax')(conv)

    return Model(inputs = inputs, outputs = conv10)

# %%
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

model = build_unet(input_layer, 'he_normal', 0.2)

model.compile(loss="categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema ,dice_coef_enhancing])

# %%
plot_model(model,
           show_shapes = True,
           show_dtype=False,
           show_layer_names = True,
           rankdir = 'TB',
           expand_nested = False,
           dpi = 70)

# %%
# !pip install pydot
# Out:
# Requirement already satisfied: pydot in ./venv/lib/python3.12/site-packages (4.0.1)
# Requirement already satisfied: pyparsing>=3.1.0 in ./venv/lib/python3.12/site-packages (from pydot) (3.3.2)
#
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
callbacks = [
      keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2,
                            patience=2, min_lr=0.000001, verbose=1),
     keras.callbacks.ModelCheckpoint(
    filepath='model_.{epoch:02d}-{val_loss:.6f}.weights.h5',
    verbose=1,
    save_best_only=True,
    save_weights_only=True
),
      CSVLogger('training.log', separator=',', append=False)
    ]

# %%
K.clear_session()

history =  model.fit(training_generator,
                    epochs=35,
                    steps_per_epoch=len(train_ids),
                    callbacks= callbacks,
                    validation_data = valid_generator
                    )
# Out:
# /home/sandeep/Documents/clg-sem-6/dip-project/venv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/35
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777035245.273123   27680 service.cc:152] XLA service 0x71070c026f90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1777035245.273151   27680 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4060 Laptop GPU, Compute Capability 8.9
# 2026-04-24 18:24:05.423706: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1777035246.158557   27680 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/250 ━━━━━━━━━━━━━━━━━━━━ 2:14:54 33s/step - accuracy: 0.0173 - dice_coef: 0.1103 - dice_coef_edema: 0.1184 - dice_coef_enhancing: 0.0436 - dice_coef_necrotic: 0.0458 - loss: 1.4588 - mean_io_u: 0.3760 - precision: 0.0754 - sensitivity: 2.2736e-04 - specificity: 0.9980
# I0000 00:00:1777035273.611109   27680 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9317 - dice_coef: 0.2512 - dice_coef_edema: 0.1017 - dice_coef_enhancing: 0.0394 - dice_coef_necrotic: 0.0340 - loss: 0.2633 - mean_io_u: 0.5093 - precision: 0.9336 - sensitivity: 0.9205 - specificity: 0.9903
# Epoch 1: val_loss improved from None to 0.10873, saving model to model_.01-0.108726.weights.h5
#
# Epoch 1: finished saving model to model_.01-0.108726.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 94s 246ms/step - accuracy: 0.9677 - dice_coef: 0.2647 - dice_coef_edema: 0.1247 - dice_coef_enhancing: 0.0482 - dice_coef_necrotic: 0.0503 - loss: 0.1564 - mean_io_u: 0.5575 - precision: 0.9690 - sensitivity: 0.9623 - specificity: 0.9919 - val_accuracy: 0.9738 - val_dice_coef: 0.2713 - val_dice_coef_edema: 0.1410 - val_dice_coef_enhancing: 0.0357 - val_dice_coef_necrotic: 0.0602 - val_loss: 0.1087 - val_mean_io_u: 0.5161 - val_precision: 0.9736 - val_sensitivity: 0.9736 - val_specificity: 0.9912 - learning_rate: 0.0010
# Epoch 2/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9760 - dice_coef: 0.2717 - dice_coef_edema: 0.1351 - dice_coef_enhancing: 0.0479 - dice_coef_necrotic: 0.0603 - loss: 0.1066 - mean_io_u: 0.6163 - precision: 0.9760 - sensitivity: 0.9756 - specificity: 0.9920
# Epoch 2: val_loss improved from 0.10873 to 0.10017, saving model to model_.02-0.100175.weights.h5
#
# Epoch 2: finished saving model to model_.02-0.100175.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 194ms/step - accuracy: 0.9756 - dice_coef: 0.2748 - dice_coef_edema: 0.1499 - dice_coef_enhancing: 0.0550 - dice_coef_necrotic: 0.0609 - loss: 0.1021 - mean_io_u: 0.6409 - precision: 0.9760 - sensitivity: 0.9743 - specificity: 0.9920 - val_accuracy: 0.9738 - val_dice_coef: 0.2858 - val_dice_coef_edema: 0.2018 - val_dice_coef_enhancing: 0.1179 - val_dice_coef_necrotic: 0.0978 - val_loss: 0.1002 - val_mean_io_u: 0.5731 - val_precision: 0.9756 - val_sensitivity: 0.9734 - val_specificity: 0.9919 - learning_rate: 0.0010
# Epoch 3/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9757 - dice_coef: 0.2802 - dice_coef_edema: 0.1658 - dice_coef_enhancing: 0.0696 - dice_coef_necrotic: 0.0766 - loss: 0.0966 - mean_io_u: 0.5987 - precision: 0.9772 - sensitivity: 0.9724 - specificity: 0.9924
# Epoch 3: val_loss improved from 0.10017 to 0.09978, saving model to model_.03-0.099782.weights.h5
#
# Epoch 3: finished saving model to model_.03-0.099782.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 192ms/step - accuracy: 0.9757 - dice_coef: 0.2805 - dice_coef_edema: 0.1661 - dice_coef_enhancing: 0.0722 - dice_coef_necrotic: 0.0721 - loss: 0.0965 - mean_io_u: 0.5790 - precision: 0.9773 - sensitivity: 0.9735 - specificity: 0.9924 - val_accuracy: 0.9738 - val_dice_coef: 0.2808 - val_dice_coef_edema: 0.1359 - val_dice_coef_enhancing: 0.0831 - val_dice_coef_necrotic: 0.0431 - val_loss: 0.0998 - val_mean_io_u: 0.4753 - val_precision: 0.9741 - val_sensitivity: 0.9737 - val_specificity: 0.9914 - learning_rate: 0.0010
# Epoch 4/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9753 - dice_coef: 0.2791 - dice_coef_edema: 0.1685 - dice_coef_enhancing: 0.0681 - dice_coef_necrotic: 0.0619 - loss: 0.0982 - mean_io_u: 0.4737 - precision: 0.9759 - sensitivity: 0.9748 - specificity: 0.9920
# Epoch 4: val_loss did not improve from 0.09978
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 197ms/step - accuracy: 0.9756 - dice_coef: 0.2801 - dice_coef_edema: 0.1624 - dice_coef_enhancing: 0.0804 - dice_coef_necrotic: 0.0661 - loss: 0.0964 - mean_io_u: 0.4630 - precision: 0.9769 - sensitivity: 0.9745 - specificity: 0.9923 - val_accuracy: 0.9738 - val_dice_coef: 0.2865 - val_dice_coef_edema: 0.1898 - val_dice_coef_enhancing: 0.1425 - val_dice_coef_necrotic: 0.0721 - val_loss: 0.1027 - val_mean_io_u: 0.3956 - val_precision: 0.9750 - val_sensitivity: 0.9732 - val_specificity: 0.9917 - learning_rate: 0.0010
# Epoch 5/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9750 - dice_coef: 0.2800 - dice_coef_edema: 0.1627 - dice_coef_enhancing: 0.0860 - dice_coef_necrotic: 0.0603 - loss: 0.1038 - mean_io_u: 0.4303 - precision: 0.9755 - sensitivity: 0.9742 - specificity: 0.9919
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
#
# Epoch 5: val_loss did not improve from 0.09978
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 46s 185ms/step - accuracy: 0.9757 - dice_coef: 0.2827 - dice_coef_edema: 0.1620 - dice_coef_enhancing: 0.0946 - dice_coef_necrotic: 0.0650 - loss: 0.0960 - mean_io_u: 0.4593 - precision: 0.9764 - sensitivity: 0.9750 - specificity: 0.9922 - val_accuracy: 0.9738 - val_dice_coef: 0.3024 - val_dice_coef_edema: 0.2150 - val_dice_coef_enhancing: 0.2661 - val_dice_coef_necrotic: 0.1296 - val_loss: 0.1014 - val_mean_io_u: 0.5004 - val_precision: 0.9778 - val_sensitivity: 0.9714 - val_specificity: 0.9926 - learning_rate: 0.0010
# Epoch 6/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9774 - dice_coef: 0.3012 - dice_coef_edema: 0.1957 - dice_coef_enhancing: 0.1889 - dice_coef_necrotic: 0.1072 - loss: 0.0788 - mean_io_u: 0.5127 - precision: 0.9798 - sensitivity: 0.9763 - specificity: 0.9933
# Epoch 6: val_loss improved from 0.09978 to 0.07805, saving model to model_.06-0.078054.weights.h5
#
# Epoch 6: finished saving model to model_.06-0.078054.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 198ms/step - accuracy: 0.9759 - dice_coef: 0.3114 - dice_coef_edema: 0.2119 - dice_coef_enhancing: 0.2013 - dice_coef_necrotic: 0.1247 - loss: 0.0790 - mean_io_u: 0.5096 - precision: 0.9806 - sensitivity: 0.9738 - specificity: 0.9935 - val_accuracy: 0.9743 - val_dice_coef: 0.3361 - val_dice_coef_edema: 0.2658 - val_dice_coef_enhancing: 0.2715 - val_dice_coef_necrotic: 0.1864 - val_loss: 0.0781 - val_mean_io_u: 0.4958 - val_precision: 0.9860 - val_sensitivity: 0.9674 - val_specificity: 0.9952 - learning_rate: 2.0000e-04
# Epoch 7/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9774 - dice_coef: 0.3294 - dice_coef_edema: 0.2624 - dice_coef_enhancing: 0.2108 - dice_coef_necrotic: 0.1647 - loss: 0.0736 - mean_io_u: 0.4938 - precision: 0.9840 - sensitivity: 0.9731 - specificity: 0.9946
# Epoch 7: val_loss improved from 0.07805 to 0.07222, saving model to model_.07-0.072217.weights.h5
#
# Epoch 7: finished saving model to model_.07-0.072217.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 194ms/step - accuracy: 0.9784 - dice_coef: 0.3371 - dice_coef_edema: 0.3002 - dice_coef_enhancing: 0.2205 - dice_coef_necrotic: 0.1700 - loss: 0.0705 - mean_io_u: 0.4937 - precision: 0.9845 - sensitivity: 0.9733 - specificity: 0.9948 - val_accuracy: 0.9769 - val_dice_coef: 0.3544 - val_dice_coef_edema: 0.2861 - val_dice_coef_enhancing: 0.2414 - val_dice_coef_necrotic: 0.1722 - val_loss: 0.0722 - val_mean_io_u: 0.5010 - val_precision: 0.9815 - val_sensitivity: 0.9738 - val_specificity: 0.9938 - learning_rate: 2.0000e-04
# Epoch 8/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9781 - dice_coef: 0.3557 - dice_coef_edema: 0.3363 - dice_coef_enhancing: 0.2882 - dice_coef_necrotic: 0.1814 - loss: 0.0736 - mean_io_u: 0.4901 - precision: 0.9835 - sensitivity: 0.9723 - specificity: 0.9944
# Epoch 8: val_loss improved from 0.07222 to 0.06663, saving model to model_.08-0.066633.weights.h5
#
# Epoch 8: finished saving model to model_.08-0.066633.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 194ms/step - accuracy: 0.9807 - dice_coef: 0.3655 - dice_coef_edema: 0.3630 - dice_coef_enhancing: 0.3113 - dice_coef_necrotic: 0.1866 - loss: 0.0642 - mean_io_u: 0.4907 - precision: 0.9858 - sensitivity: 0.9752 - specificity: 0.9952 - val_accuracy: 0.9793 - val_dice_coef: 0.3785 - val_dice_coef_edema: 0.3861 - val_dice_coef_enhancing: 0.3533 - val_dice_coef_necrotic: 0.1767 - val_loss: 0.0666 - val_mean_io_u: 0.5008 - val_precision: 0.9846 - val_sensitivity: 0.9738 - val_specificity: 0.9947 - learning_rate: 2.0000e-04
# Epoch 9/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9827 - dice_coef: 0.3941 - dice_coef_edema: 0.4114 - dice_coef_enhancing: 0.3891 - dice_coef_necrotic: 0.2092 - loss: 0.0551 - mean_io_u: 0.4967 - precision: 0.9875 - sensitivity: 0.9777 - specificity: 0.9957
# Epoch 9: val_loss did not improve from 0.06663
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 193ms/step - accuracy: 0.9818 - dice_coef: 0.3928 - dice_coef_edema: 0.4212 - dice_coef_enhancing: 0.3704 - dice_coef_necrotic: 0.2118 - loss: 0.0575 - mean_io_u: 0.4927 - precision: 0.9867 - sensitivity: 0.9768 - specificity: 0.9955 - val_accuracy: 0.9792 - val_dice_coef: 0.3813 - val_dice_coef_edema: 0.3764 - val_dice_coef_enhancing: 0.3143 - val_dice_coef_necrotic: 0.1735 - val_loss: 0.0670 - val_mean_io_u: 0.4985 - val_precision: 0.9821 - val_sensitivity: 0.9766 - val_specificity: 0.9940 - learning_rate: 2.0000e-04
# Epoch 10/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9823 - dice_coef: 0.4062 - dice_coef_edema: 0.4390 - dice_coef_enhancing: 0.3979 - dice_coef_necrotic: 0.2309 - loss: 0.0566 - mean_io_u: 0.4951 - precision: 0.9866 - sensitivity: 0.9777 - specificity: 0.9954
# Epoch 10: val_loss improved from 0.06663 to 0.05481, saving model to model_.10-0.054809.weights.h5
#
# Epoch 10: finished saving model to model_.10-0.054809.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 51s 204ms/step - accuracy: 0.9827 - dice_coef: 0.4110 - dice_coef_edema: 0.4460 - dice_coef_enhancing: 0.4256 - dice_coef_necrotic: 0.2306 - loss: 0.0550 - mean_io_u: 0.4902 - precision: 0.9868 - sensitivity: 0.9782 - specificity: 0.9955 - val_accuracy: 0.9817 - val_dice_coef: 0.4371 - val_dice_coef_edema: 0.4591 - val_dice_coef_enhancing: 0.4665 - val_dice_coef_necrotic: 0.2506 - val_loss: 0.0548 - val_mean_io_u: 0.4893 - val_precision: 0.9857 - val_sensitivity: 0.9782 - val_specificity: 0.9951 - learning_rate: 2.0000e-04
# Epoch 11/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9848 - dice_coef: 0.4417 - dice_coef_edema: 0.5129 - dice_coef_enhancing: 0.4659 - dice_coef_necrotic: 0.2534 - loss: 0.0462 - mean_io_u: 0.4898 - precision: 0.9883 - sensitivity: 0.9806 - specificity: 0.9960
# Epoch 11: val_loss improved from 0.05481 to 0.04891, saving model to model_.11-0.048907.weights.h5
#
# Epoch 11: finished saving model to model_.11-0.048907.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 195ms/step - accuracy: 0.9845 - dice_coef: 0.4406 - dice_coef_edema: 0.4944 - dice_coef_enhancing: 0.4641 - dice_coef_necrotic: 0.2668 - loss: 0.0469 - mean_io_u: 0.4908 - precision: 0.9881 - sensitivity: 0.9803 - specificity: 0.9959 - val_accuracy: 0.9831 - val_dice_coef: 0.4542 - val_dice_coef_edema: 0.4415 - val_dice_coef_enhancing: 0.5481 - val_dice_coef_necrotic: 0.3278 - val_loss: 0.0489 - val_mean_io_u: 0.5009 - val_precision: 0.9884 - val_sensitivity: 0.9769 - val_specificity: 0.9960 - learning_rate: 2.0000e-04
# Epoch 12/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9854 - dice_coef: 0.4470 - dice_coef_edema: 0.4873 - dice_coef_enhancing: 0.4702 - dice_coef_necrotic: 0.3097 - loss: 0.0432 - mean_io_u: 0.5028 - precision: 0.9892 - sensitivity: 0.9809 - specificity: 0.9963
# Epoch 12: val_loss improved from 0.04891 to 0.04849, saving model to model_.12-0.048489.weights.h5
#
# Epoch 12: finished saving model to model_.12-0.048489.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 193ms/step - accuracy: 0.9840 - dice_coef: 0.4418 - dice_coef_edema: 0.5030 - dice_coef_enhancing: 0.4636 - dice_coef_necrotic: 0.2580 - loss: 0.0476 - mean_io_u: 0.5016 - precision: 0.9878 - sensitivity: 0.9798 - specificity: 0.9958 - val_accuracy: 0.9830 - val_dice_coef: 0.4568 - val_dice_coef_edema: 0.5206 - val_dice_coef_enhancing: 0.5250 - val_dice_coef_necrotic: 0.2520 - val_loss: 0.0485 - val_mean_io_u: 0.5063 - val_precision: 0.9874 - val_sensitivity: 0.9791 - val_specificity: 0.9957 - learning_rate: 2.0000e-04
# Epoch 13/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9856 - dice_coef: 0.4602 - dice_coef_edema: 0.5380 - dice_coef_enhancing: 0.5086 - dice_coef_necrotic: 0.2785 - loss: 0.0421 - mean_io_u: 0.5140 - precision: 0.9893 - sensitivity: 0.9813 - specificity: 0.9963
# Epoch 13: val_loss improved from 0.04849 to 0.04588, saving model to model_.13-0.045879.weights.h5
#
# Epoch 13: finished saving model to model_.13-0.045879.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 198ms/step - accuracy: 0.9853 - dice_coef: 0.4609 - dice_coef_edema: 0.5346 - dice_coef_enhancing: 0.4976 - dice_coef_necrotic: 0.2911 - loss: 0.0425 - mean_io_u: 0.5048 - precision: 0.9890 - sensitivity: 0.9812 - specificity: 0.9962 - val_accuracy: 0.9840 - val_dice_coef: 0.4882 - val_dice_coef_edema: 0.5766 - val_dice_coef_enhancing: 0.5236 - val_dice_coef_necrotic: 0.3997 - val_loss: 0.0459 - val_mean_io_u: 0.4946 - val_precision: 0.9879 - val_sensitivity: 0.9791 - val_specificity: 0.9958 - learning_rate: 2.0000e-04
# Epoch 14/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9867 - dice_coef: 0.4925 - dice_coef_edema: 0.5709 - dice_coef_enhancing: 0.5465 - dice_coef_necrotic: 0.3552 - loss: 0.0381 - mean_io_u: 0.5074 - precision: 0.9901 - sensitivity: 0.9824 - specificity: 0.9966
# Epoch 14: val_loss did not improve from 0.04588
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 196ms/step - accuracy: 0.9861 - dice_coef: 0.4832 - dice_coef_edema: 0.5634 - dice_coef_enhancing: 0.5237 - dice_coef_necrotic: 0.3406 - loss: 0.0408 - mean_io_u: 0.5007 - precision: 0.9893 - sensitivity: 0.9821 - specificity: 0.9963 - val_accuracy: 0.9835 - val_dice_coef: 0.4805 - val_dice_coef_edema: 0.5303 - val_dice_coef_enhancing: 0.5714 - val_dice_coef_necrotic: 0.3785 - val_loss: 0.0479 - val_mean_io_u: 0.4710 - val_precision: 0.9876 - val_sensitivity: 0.9783 - val_specificity: 0.9958 - learning_rate: 2.0000e-04
# Epoch 15/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9863 - dice_coef: 0.4700 - dice_coef_edema: 0.5623 - dice_coef_enhancing: 0.4470 - dice_coef_necrotic: 0.3413 - loss: 0.0393 - mean_io_u: 0.4918 - precision: 0.9896 - sensitivity: 0.9820 - specificity: 0.9964
# Epoch 15: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
#
# Epoch 15: val_loss did not improve from 0.04588
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 201ms/step - accuracy: 0.9868 - dice_coef: 0.4908 - dice_coef_edema: 0.5867 - dice_coef_enhancing: 0.5170 - dice_coef_necrotic: 0.3584 - loss: 0.0379 - mean_io_u: 0.5075 - precision: 0.9898 - sensitivity: 0.9829 - specificity: 0.9965 - val_accuracy: 0.9845 - val_dice_coef: 0.5113 - val_dice_coef_edema: 0.5617 - val_dice_coef_enhancing: 0.5762 - val_dice_coef_necrotic: 0.3914 - val_loss: 0.0467 - val_mean_io_u: 0.5243 - val_precision: 0.9868 - val_sensitivity: 0.9816 - val_specificity: 0.9955 - learning_rate: 2.0000e-04
# Epoch 16/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9870 - dice_coef: 0.5132 - dice_coef_edema: 0.6294 - dice_coef_enhancing: 0.4996 - dice_coef_necrotic: 0.4395 - loss: 0.0359 - mean_io_u: 0.5366 - precision: 0.9896 - sensitivity: 0.9834 - specificity: 0.9965
# Epoch 16: val_loss improved from 0.04588 to 0.04143, saving model to model_.16-0.041434.weights.h5
#
# Epoch 16: finished saving model to model_.16-0.041434.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 197ms/step - accuracy: 0.9885 - dice_coef: 0.5241 - dice_coef_edema: 0.6341 - dice_coef_enhancing: 0.5605 - dice_coef_necrotic: 0.4232 - loss: 0.0326 - mean_io_u: 0.5409 - precision: 0.9907 - sensitivity: 0.9851 - specificity: 0.9968 - val_accuracy: 0.9859 - val_dice_coef: 0.5357 - val_dice_coef_edema: 0.6190 - val_dice_coef_enhancing: 0.6200 - val_dice_coef_necrotic: 0.4205 - val_loss: 0.0414 - val_mean_io_u: 0.5421 - val_precision: 0.9883 - val_sensitivity: 0.9825 - val_specificity: 0.9960 - learning_rate: 4.0000e-05
# Epoch 17/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9889 - dice_coef: 0.5228 - dice_coef_edema: 0.6148 - dice_coef_enhancing: 0.5626 - dice_coef_necrotic: 0.4077 - loss: 0.0317 - mean_io_u: 0.5457 - precision: 0.9912 - sensitivity: 0.9854 - specificity: 0.9970
# Epoch 17: val_loss did not improve from 0.04143
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 198ms/step - accuracy: 0.9889 - dice_coef: 0.5367 - dice_coef_edema: 0.6465 - dice_coef_enhancing: 0.5730 - dice_coef_necrotic: 0.4410 - loss: 0.0312 - mean_io_u: 0.5547 - precision: 0.9910 - sensitivity: 0.9856 - specificity: 0.9969 - val_accuracy: 0.9861 - val_dice_coef: 0.5422 - val_dice_coef_edema: 0.6239 - val_dice_coef_enhancing: 0.6139 - val_dice_coef_necrotic: 0.4335 - val_loss: 0.0416 - val_mean_io_u: 0.5592 - val_precision: 0.9883 - val_sensitivity: 0.9829 - val_specificity: 0.9960 - learning_rate: 4.0000e-05
# Epoch 18/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9891 - dice_coef: 0.5364 - dice_coef_edema: 0.6603 - dice_coef_enhancing: 0.5475 - dice_coef_necrotic: 0.4399 - loss: 0.0307 - mean_io_u: 0.5612 - precision: 0.9909 - sensitivity: 0.9861 - specificity: 0.9969
# Epoch 18: val_loss improved from 0.04143 to 0.04112, saving model to model_.18-0.041123.weights.h5
#
# Epoch 18: finished saving model to model_.18-0.041123.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 192ms/step - accuracy: 0.9892 - dice_coef: 0.5428 - dice_coef_edema: 0.6553 - dice_coef_enhancing: 0.5748 - dice_coef_necrotic: 0.4456 - loss: 0.0305 - mean_io_u: 0.5671 - precision: 0.9910 - sensitivity: 0.9861 - specificity: 0.9969 - val_accuracy: 0.9861 - val_dice_coef: 0.5439 - val_dice_coef_edema: 0.6011 - val_dice_coef_enhancing: 0.6306 - val_dice_coef_necrotic: 0.4522 - val_loss: 0.0411 - val_mean_io_u: 0.5781 - val_precision: 0.9884 - val_sensitivity: 0.9826 - val_specificity: 0.9960 - learning_rate: 4.0000e-05
# Epoch 19/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9903 - dice_coef: 0.5371 - dice_coef_edema: 0.6274 - dice_coef_enhancing: 0.5731 - dice_coef_necrotic: 0.4392 - loss: 0.0274 - mean_io_u: 0.5682 - precision: 0.9920 - sensitivity: 0.9875 - specificity: 0.9973
# Epoch 19: val_loss improved from 0.04112 to 0.04011, saving model to model_.19-0.040108.weights.h5
#
# Epoch 19: finished saving model to model_.19-0.040108.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 196ms/step - accuracy: 0.9893 - dice_coef: 0.5479 - dice_coef_edema: 0.6606 - dice_coef_enhancing: 0.5786 - dice_coef_necrotic: 0.4537 - loss: 0.0301 - mean_io_u: 0.5758 - precision: 0.9911 - sensitivity: 0.9863 - specificity: 0.9970 - val_accuracy: 0.9864 - val_dice_coef: 0.5472 - val_dice_coef_edema: 0.6320 - val_dice_coef_enhancing: 0.6322 - val_dice_coef_necrotic: 0.4440 - val_loss: 0.0401 - val_mean_io_u: 0.5689 - val_precision: 0.9884 - val_sensitivity: 0.9830 - val_specificity: 0.9961 - learning_rate: 4.0000e-05
# Epoch 20/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9891 - dice_coef: 0.5531 - dice_coef_edema: 0.6559 - dice_coef_enhancing: 0.5932 - dice_coef_necrotic: 0.4776 - loss: 0.0304 - mean_io_u: 0.5710 - precision: 0.9910 - sensitivity: 0.9859 - specificity: 0.9969
# Epoch 20: val_loss did not improve from 0.04011
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 198ms/step - accuracy: 0.9895 - dice_coef: 0.5518 - dice_coef_edema: 0.6632 - dice_coef_enhancing: 0.5842 - dice_coef_necrotic: 0.4625 - loss: 0.0295 - mean_io_u: 0.5776 - precision: 0.9912 - sensitivity: 0.9865 - specificity: 0.9970 - val_accuracy: 0.9862 - val_dice_coef: 0.5506 - val_dice_coef_edema: 0.6544 - val_dice_coef_enhancing: 0.5954 - val_dice_coef_necrotic: 0.4335 - val_loss: 0.0412 - val_mean_io_u: 0.5822 - val_precision: 0.9876 - val_sensitivity: 0.9836 - val_specificity: 0.9958 - learning_rate: 4.0000e-05
# Epoch 21/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9890 - dice_coef: 0.5597 - dice_coef_edema: 0.6691 - dice_coef_enhancing: 0.5958 - dice_coef_necrotic: 0.4730 - loss: 0.0305 - mean_io_u: 0.5886 - precision: 0.9906 - sensitivity: 0.9860 - specificity: 0.9968
# Epoch 21: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
#
# Epoch 21: val_loss did not improve from 0.04011
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 197ms/step - accuracy: 0.9897 - dice_coef: 0.5553 - dice_coef_edema: 0.6703 - dice_coef_enhancing: 0.5852 - dice_coef_necrotic: 0.4716 - loss: 0.0289 - mean_io_u: 0.5907 - precision: 0.9913 - sensitivity: 0.9867 - specificity: 0.9970 - val_accuracy: 0.9866 - val_dice_coef: 0.5576 - val_dice_coef_edema: 0.6305 - val_dice_coef_enhancing: 0.6399 - val_dice_coef_necrotic: 0.4385 - val_loss: 0.0410 - val_mean_io_u: 0.6223 - val_precision: 0.9882 - val_sensitivity: 0.9838 - val_specificity: 0.9960 - learning_rate: 4.0000e-05
# Epoch 22/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9901 - dice_coef: 0.5587 - dice_coef_edema: 0.6826 - dice_coef_enhancing: 0.5818 - dice_coef_necrotic: 0.4691 - loss: 0.0277 - mean_io_u: 0.6032 - precision: 0.9916 - sensitivity: 0.9872 - specificity: 0.9971
# Epoch 22: val_loss improved from 0.04011 to 0.03969, saving model to model_.22-0.039691.weights.h5
#
# Epoch 22: finished saving model to model_.22-0.039691.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 192ms/step - accuracy: 0.9901 - dice_coef: 0.5627 - dice_coef_edema: 0.6777 - dice_coef_enhancing: 0.5947 - dice_coef_necrotic: 0.4799 - loss: 0.0277 - mean_io_u: 0.5988 - precision: 0.9915 - sensitivity: 0.9872 - specificity: 0.9971 - val_accuracy: 0.9869 - val_dice_coef: 0.5639 - val_dice_coef_edema: 0.6518 - val_dice_coef_enhancing: 0.6366 - val_dice_coef_necrotic: 0.4662 - val_loss: 0.0397 - val_mean_io_u: 0.6104 - val_precision: 0.9886 - val_sensitivity: 0.9840 - val_specificity: 0.9961 - learning_rate: 8.0000e-06
# Epoch 23/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9897 - dice_coef: 0.5644 - dice_coef_edema: 0.6888 - dice_coef_enhancing: 0.5658 - dice_coef_necrotic: 0.4951 - loss: 0.0283 - mean_io_u: 0.6084 - precision: 0.9912 - sensitivity: 0.9868 - specificity: 0.9970
# Epoch 23: val_loss improved from 0.03969 to 0.03964, saving model to model_.23-0.039640.weights.h5
#
# Epoch 23: finished saving model to model_.23-0.039640.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 194ms/step - accuracy: 0.9901 - dice_coef: 0.5658 - dice_coef_edema: 0.6842 - dice_coef_enhancing: 0.5936 - dice_coef_necrotic: 0.4889 - loss: 0.0275 - mean_io_u: 0.6061 - precision: 0.9916 - sensitivity: 0.9873 - specificity: 0.9971 - val_accuracy: 0.9869 - val_dice_coef: 0.5631 - val_dice_coef_edema: 0.6522 - val_dice_coef_enhancing: 0.6367 - val_dice_coef_necrotic: 0.4590 - val_loss: 0.0396 - val_mean_io_u: 0.6100 - val_precision: 0.9885 - val_sensitivity: 0.9841 - val_specificity: 0.9961 - learning_rate: 8.0000e-06
# Epoch 24/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9907 - dice_coef: 0.5737 - dice_coef_edema: 0.6850 - dice_coef_enhancing: 0.6132 - dice_coef_necrotic: 0.5076 - loss: 0.0261 - mean_io_u: 0.6059 - precision: 0.9919 - sensitivity: 0.9880 - specificity: 0.9972
# Epoch 24: val_loss improved from 0.03964 to 0.03913, saving model to model_.24-0.039128.weights.h5
#
# Epoch 24: finished saving model to model_.24-0.039128.weights.h5
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 200ms/step - accuracy: 0.9902 - dice_coef: 0.5674 - dice_coef_edema: 0.6856 - dice_coef_enhancing: 0.5954 - dice_coef_necrotic: 0.4878 - loss: 0.0273 - mean_io_u: 0.6045 - precision: 0.9916 - sensitivity: 0.9875 - specificity: 0.9971 - val_accuracy: 0.9870 - val_dice_coef: 0.5665 - val_dice_coef_edema: 0.6559 - val_dice_coef_enhancing: 0.6439 - val_dice_coef_necrotic: 0.4726 - val_loss: 0.0391 - val_mean_io_u: 0.6132 - val_precision: 0.9887 - val_sensitivity: 0.9841 - val_specificity: 0.9962 - learning_rate: 8.0000e-06
# Epoch 25/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9902 - dice_coef: 0.5779 - dice_coef_edema: 0.6860 - dice_coef_enhancing: 0.6249 - dice_coef_necrotic: 0.5255 - loss: 0.0272 - mean_io_u: 0.6176 - precision: 0.9917 - sensitivity: 0.9874 - specificity: 0.9972
# Epoch 25: val_loss did not improve from 0.03913
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 199ms/step - accuracy: 0.9903 - dice_coef: 0.5678 - dice_coef_edema: 0.6854 - dice_coef_enhancing: 0.5984 - dice_coef_necrotic: 0.4908 - loss: 0.0272 - mean_io_u: 0.6098 - precision: 0.9916 - sensitivity: 0.9875 - specificity: 0.9971 - val_accuracy: 0.9868 - val_dice_coef: 0.5640 - val_dice_coef_edema: 0.6567 - val_dice_coef_enhancing: 0.6280 - val_dice_coef_necrotic: 0.4553 - val_loss: 0.0402 - val_mean_io_u: 0.6239 - val_precision: 0.9883 - val_sensitivity: 0.9842 - val_specificity: 0.9961 - learning_rate: 8.0000e-06
# Epoch 26/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9900 - dice_coef: 0.5683 - dice_coef_edema: 0.6776 - dice_coef_enhancing: 0.5978 - dice_coef_necrotic: 0.4930 - loss: 0.0277 - mean_io_u: 0.6187 - precision: 0.9913 - sensitivity: 0.9872 - specificity: 0.9970
# Epoch 26: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
#
# Epoch 26: val_loss did not improve from 0.03913
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 195ms/step - accuracy: 0.9903 - dice_coef: 0.5693 - dice_coef_edema: 0.6875 - dice_coef_enhancing: 0.5965 - dice_coef_necrotic: 0.4934 - loss: 0.0271 - mean_io_u: 0.6205 - precision: 0.9916 - sensitivity: 0.9876 - specificity: 0.9971 - val_accuracy: 0.9869 - val_dice_coef: 0.5678 - val_dice_coef_edema: 0.6603 - val_dice_coef_enhancing: 0.6378 - val_dice_coef_necrotic: 0.4616 - val_loss: 0.0399 - val_mean_io_u: 0.6275 - val_precision: 0.9884 - val_sensitivity: 0.9843 - val_specificity: 0.9961 - learning_rate: 8.0000e-06
# Epoch 27/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9904 - dice_coef: 0.5817 - dice_coef_edema: 0.7025 - dice_coef_enhancing: 0.6103 - dice_coef_necrotic: 0.5126 - loss: 0.0267 - mean_io_u: 0.6269 - precision: 0.9916 - sensitivity: 0.9877 - specificity: 0.9971
# Epoch 27: val_loss did not improve from 0.03913
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 50s 199ms/step - accuracy: 0.9904 - dice_coef: 0.5720 - dice_coef_edema: 0.6917 - dice_coef_enhancing: 0.5982 - dice_coef_necrotic: 0.4939 - loss: 0.0268 - mean_io_u: 0.6208 - precision: 0.9916 - sensitivity: 0.9877 - specificity: 0.9972 - val_accuracy: 0.9870 - val_dice_coef: 0.5680 - val_dice_coef_edema: 0.6604 - val_dice_coef_enhancing: 0.6398 - val_dice_coef_necrotic: 0.4655 - val_loss: 0.0396 - val_mean_io_u: 0.6269 - val_precision: 0.9885 - val_sensitivity: 0.9842 - val_specificity: 0.9961 - learning_rate: 1.6000e-06
# Epoch 28/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.9898 - dice_coef: 0.5791 - dice_coef_edema: 0.6900 - dice_coef_enhancing: 0.6122 - dice_coef_necrotic: 0.5104 - loss: 0.0282 - mean_io_u: 0.6252 - precision: 0.9912 - sensitivity: 0.9869 - specificity: 0.9970
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 28: val_loss did not improve from 0.03913
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 197ms/step - accuracy: 0.9904 - dice_coef: 0.5721 - dice_coef_edema: 0.6915 - dice_coef_enhancing: 0.5985 - dice_coef_necrotic: 0.4954 - loss: 0.0267 - mean_io_u: 0.6219 - precision: 0.9917 - sensitivity: 0.9877 - specificity: 0.9972 - val_accuracy: 0.9870 - val_dice_coef: 0.5685 - val_dice_coef_edema: 0.6614 - val_dice_coef_enhancing: 0.6416 - val_dice_coef_necrotic: 0.4687 - val_loss: 0.0394 - val_mean_io_u: 0.6259 - val_precision: 0.9885 - val_sensitivity: 0.9842 - val_specificity: 0.9961 - learning_rate: 1.6000e-06
# Epoch 29/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.9907 - dice_coef: 0.5609 - dice_coef_edema: 0.6705 - dice_coef_enhancing: 0.5583 - dice_coef_necrotic: 0.4979 - loss: 0.0257 - mean_io_u: 0.6162 - precision: 0.9920 - sensitivity: 0.9880 - specificity: 0.9973
# Epoch 29: val_loss did not improve from 0.03913
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 193ms/step - accuracy: 0.9904 - dice_coef: 0.5723 - dice_coef_edema: 0.6921 - dice_coef_enhancing: 0.5994 - dice_coef_necrotic: 0.4976 - loss: 0.0267 - mean_io_u: 0.6216 - precision: 0.9917 - sensitivity: 0.9877 - specificity: 0.9972 - val_accuracy: 0.9870 - val_dice_coef: 0.5681 - val_dice_coef_edema: 0.6600 - val_dice_coef_enhancing: 0.6401 - val_dice_coef_necrotic: 0.4653 - val_loss: 0.0396 - val_mean_io_u: 0.6285 - val_precision: 0.9885 - val_sensitivity: 0.9843 - val_specificity: 0.9961 - learning_rate: 1.0000e-06
# Epoch 30/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.9906 - dice_coef: 0.5702 - dice_coef_edema: 0.6886 - dice_coef_enhancing: 0.5911 - dice_coef_necrotic: 0.5084 - loss: 0.0262 - mean_io_u: 0.6178 - precision: 0.9919 - sensitivity: 0.9879 - specificity: 0.9972
# Epoch 30: val_loss did not improve from 0.03913
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 48s 193ms/step - accuracy: 0.9904 - dice_coef: 0.5725 - dice_coef_edema: 0.6926 - dice_coef_enhancing: 0.5981 - dice_coef_necrotic: 0.4959 - loss: 0.0267 - mean_io_u: 0.6222 - precision: 0.9917 - sensitivity: 0.9878 - specificity: 0.9972 - val_accuracy: 0.9870 - val_dice_coef: 0.5686 - val_dice_coef_edema: 0.6611 - val_dice_coef_enhancing: 0.6418 - val_dice_coef_necrotic: 0.4686 - val_loss: 0.0394 - val_mean_io_u: 0.6275 - val_precision: 0.9885 - val_sensitivity: 0.9842 - val_specificity: 0.9961 - learning_rate: 1.0000e-06
# Epoch 31/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9900 - dice_coef: 0.5740 - dice_coef_edema: 0.6766 - dice_coef_enhancing: 0.6048 - dice_coef_necrotic: 0.5120 - loss: 0.0278 - mean_io_u: 0.6220 - precision: 0.9914 - sensitivity: 0.9871 - specificity: 0.9971
# Epoch 31: val_loss did not improve from 0.03913
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 196ms/step - accuracy: 0.9904 - dice_coef: 0.5725 - dice_coef_edema: 0.6918 - dice_coef_enhancing: 0.5996 - dice_coef_necrotic: 0.4984 - loss: 0.0267 - mean_io_u: 0.6225 - precision: 0.9917 - sensitivity: 0.9877 - specificity: 0.9972 - val_accuracy: 0.9870 - val_dice_coef: 0.5684 - val_dice_coef_edema: 0.6601 - val_dice_coef_enhancing: 0.6400 - val_dice_coef_necrotic: 0.4660 - val_loss: 0.0396 - val_mean_io_u: 0.6303 - val_precision: 0.9885 - val_sensitivity: 0.9843 - val_specificity: 0.9961 - learning_rate: 1.0000e-06
# Epoch 32/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9905 - dice_coef: 0.5791 - dice_coef_edema: 0.7001 - dice_coef_enhancing: 0.6258 - dice_coef_necrotic: 0.4907 - loss: 0.0265 - mean_io_u: 0.6266 - precision: 0.9917 - sensitivity: 0.9879 - specificity: 0.9972
# Epoch 32: val_loss did not improve from 0.03913
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 194ms/step - accuracy: 0.9904 - dice_coef: 0.5729 - dice_coef_edema: 0.6924 - dice_coef_enhancing: 0.5987 - dice_coef_necrotic: 0.4972 - loss: 0.0266 - mean_io_u: 0.6242 - precision: 0.9917 - sensitivity: 0.9878 - specificity: 0.9972 - val_accuracy: 0.9870 - val_dice_coef: 0.5689 - val_dice_coef_edema: 0.6611 - val_dice_coef_enhancing: 0.6425 - val_dice_coef_necrotic: 0.4691 - val_loss: 0.0394 - val_mean_io_u: 0.6298 - val_precision: 0.9885 - val_sensitivity: 0.9843 - val_specificity: 0.9961 - learning_rate: 1.0000e-06
# Epoch 33/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step - accuracy: 0.9903 - dice_coef: 0.5800 - dice_coef_edema: 0.7100 - dice_coef_enhancing: 0.6175 - dice_coef_necrotic: 0.5037 - loss: 0.0268 - mean_io_u: 0.6314 - precision: 0.9917 - sensitivity: 0.9874 - specificity: 0.9972
# Epoch 33: val_loss did not improve from 0.03913
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 52s 206ms/step - accuracy: 0.9904 - dice_coef: 0.5729 - dice_coef_edema: 0.6927 - dice_coef_enhancing: 0.5998 - dice_coef_necrotic: 0.4978 - loss: 0.0266 - mean_io_u: 0.6250 - precision: 0.9917 - sensitivity: 0.9878 - specificity: 0.9972 - val_accuracy: 0.9870 - val_dice_coef: 0.5690 - val_dice_coef_edema: 0.6613 - val_dice_coef_enhancing: 0.6421 - val_dice_coef_necrotic: 0.4690 - val_loss: 0.0394 - val_mean_io_u: 0.6302 - val_precision: 0.9885 - val_sensitivity: 0.9843 - val_specificity: 0.9961 - learning_rate: 1.0000e-06
# Epoch 34/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9898 - dice_coef: 0.5848 - dice_coef_edema: 0.7115 - dice_coef_enhancing: 0.6236 - dice_coef_necrotic: 0.5199 - loss: 0.0282 - mean_io_u: 0.6299 - precision: 0.9911 - sensitivity: 0.9870 - specificity: 0.9970
# Epoch 34: val_loss did not improve from 0.03913
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 195ms/step - accuracy: 0.9904 - dice_coef: 0.5731 - dice_coef_edema: 0.6929 - dice_coef_enhancing: 0.6001 - dice_coef_necrotic: 0.4984 - loss: 0.0266 - mean_io_u: 0.6250 - precision: 0.9917 - sensitivity: 0.9878 - specificity: 0.9972 - val_accuracy: 0.9870 - val_dice_coef: 0.5691 - val_dice_coef_edema: 0.6611 - val_dice_coef_enhancing: 0.6417 - val_dice_coef_necrotic: 0.4685 - val_loss: 0.0394 - val_mean_io_u: 0.6319 - val_precision: 0.9885 - val_sensitivity: 0.9843 - val_specificity: 0.9961 - learning_rate: 1.0000e-06
# Epoch 35/35
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9900 - dice_coef: 0.5674 - dice_coef_edema: 0.6823 - dice_coef_enhancing: 0.5726 - dice_coef_necrotic: 0.5044 - loss: 0.0275 - mean_io_u: 0.6310 - precision: 0.9914 - sensitivity: 0.9873 - specificity: 0.9971
# Epoch 35: val_loss did not improve from 0.03913
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 49s 196ms/step - accuracy: 0.9905 - dice_coef: 0.5735 - dice_coef_edema: 0.6933 - dice_coef_enhancing: 0.5999 - dice_coef_necrotic: 0.4994 - loss: 0.0266 - mean_io_u: 0.6269 - precision: 0.9917 - sensitivity: 0.9878 - specificity: 0.9972 - val_accuracy: 0.9870 - val_dice_coef: 0.5689 - val_dice_coef_edema: 0.6605 - val_dice_coef_enhancing: 0.6403 - val_dice_coef_necrotic: 0.4666 - val_loss: 0.0396 - val_mean_io_u: 0.6344 - val_precision: 0.9885 - val_sensitivity: 0.9843 - val_specificity: 0.9961 - learning_rate: 1.0000e-06

# %%
model.save("model_02.keras")

# %%
model = keras.models.load_model('model_02.keras',
                                   custom_objects={"accuracy" : tf.keras.metrics.MeanIoU(num_classes=4),
                                                   "dice_coef" : dice_coef,
                                                   "precision" : precision,
                                                   "sensitivity" :sensitivity,
                                                   "specificity" :specificity,
                                                   "dice_coef_necrotic" : dice_coef_necrotic,
                                                   "dice_coef_edema" : dice_coef_edema,
                                                   "dice_coef_enhancing" : dice_coef_enhancing
                                                  }, compile=False)

# %%
history = pd.read_csv('training.log', sep=',', engine='python')

hist=history

acc=hist['accuracy']
val_acc=hist['val_accuracy']

epoch=range(len(acc))

loss=hist['loss']
val_loss=hist['val_loss']

train_dice=hist['dice_coef']
val_dice=hist['val_dice_coef']

f,ax=plt.subplots(1,4,figsize=(16,8))

ax[0].plot(epoch,acc,'b',label='Training Accuracy')
ax[0].plot(epoch,val_acc,'r',label='Validation Accuracy')
ax[0].legend()

ax[1].plot(epoch,loss,'b',label='Training Loss')
ax[1].plot(epoch,val_loss,'r',label='Validation Loss')
ax[1].legend()

ax[2].plot(epoch,train_dice,'b',label='Training dice coef')
ax[2].plot(epoch,val_dice,'r',label='Validation dice coef')
ax[2].legend()

ax[3].plot(epoch,hist['mean_io_u'],'b',label='Training mean IOU')
ax[3].plot(epoch,hist['val_mean_io_u'],'r',label='Validation mean IOU')
ax[3].legend()

plt.show()

# %%
# Compile a model and load our saved weights
IMG_SIZE = 128
input_layer = Input((IMG_SIZE, IMG_SIZE, 2))

best_saved_model = build_unet(input_layer, 'he_normal', 0.2)

best_saved_model.compile(loss="categorical_crossentropy", optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema, dice_coef_enhancing])

best_saved_model.load_weights('model_.24-0.039128.weights.h5')
# Out:
# /home/sandeep/Documents/clg-sem-6/dip-project/venv/lib/python3.12/site-packages/keras/src/saving/saving_lib.py:801: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 94 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
import os
print(os.listdir())
# Out:
# ['model_01.keras', 'brats20-dataset-training-validation.zip', 'brain-tumor.ipynb', 'venv', 'training.log', 'model.png', 'model_.01-nan.weights.h5', 'brain-tumor-segmentation-using-u-net.ipynb', 'requirements.txt', 'BraTS2020_ValidationData', 'BraTS2020_TrainingData']

# %%
def imageLoader(path):
    image = nib.load(path).get_fdata()
    X = np.zeros((self.batch_size*VOLUME_SLICES, *self.dim, self.n_channels))
    for j in range(VOLUME_SLICES):
        X[j +VOLUME_SLICES*c,:,:,0] = cv2.resize(image[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));
        X[j +VOLUME_SLICES*c,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE));

        y[j +VOLUME_SLICES*c] = seg[:,:,j+VOLUME_START_AT];
    return np.array(image)

# %%
def loadDataFromDir(path, list_of_files, mriType, n_images):
    scans = []
    masks = []
    for i in list_of_files[:n_images]:
        fullPath = glob.glob( i + '/*'+ mriType +'*')[0]
        currentScanVolume = imageLoader(fullPath)
        currentMaskVolume = imageLoader( glob.glob( i + '/*seg*')[0] )
        # for each slice in 3D volume, find also it's mask
        for j in range(0, currentScanVolume.shape[2]):
            scan_img = cv2.resize(currentScanVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            mask_img = cv2.resize(currentMaskVolume[:,:,j], dsize=(IMG_SIZE,IMG_SIZE), interpolation=cv2.INTER_AREA).astype('uint8')
            scans.append(scan_img[..., np.newaxis])
            masks.append(mask_img[..., np.newaxis])
    return np.array(scans, dtype='float32'), np.array(masks, dtype='float32')

# %%
def predictByPath(case_path,case):
    files = next(os.walk(case_path))[2]
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))

    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_flair.nii');
    flair=nib.load(vol_path).get_fdata()

    vol_path = os.path.join(case_path, f'BraTS20_Training_{case}_t1ce.nii');
    ce=nib.load(vol_path).get_fdata()


    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))

    return model.predict(X/np.max(X), verbose=1)

# %%
def showPredictsById(case, start_slice = 30):
    path = f"BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
    gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
    origImage = nib.load(os.path.join(path, f'BraTS20_Training_{case}_flair.nii')).get_fdata()
    p = predictByPath(path,case)

    core = p[:,:,:,1]
    edema= p[:,:,:,2]
    enhancing = p[:,:,:,3]

    plt.figure(figsize=(18, 50))
    f, axarr = plt.subplots(1,6, figsize = (18, 50))

    for i in range(6): # for each image, add brain background
        axarr[i].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray", interpolation='none')

    axarr[0].imshow(cv2.resize(origImage[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE)), cmap="gray")
    axarr[0].title.set_text('Original image flair')
    curr_gt=cv2.resize(gt[:,:,start_slice+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)
    axarr[1].imshow(curr_gt, cmap="Reds", interpolation='none', alpha=0.3) # ,alpha=0.3,cmap='Reds'
    axarr[1].title.set_text('Ground truth')
    axarr[2].imshow(p[start_slice,:,:,1:4], cmap="Reds", interpolation='none', alpha=0.3)
    axarr[2].title.set_text('all classes predicted')
    axarr[3].imshow(edema[start_slice,:,:], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[3].title.set_text(f'{SEGMENT_CLASSES[1]} predicted')
    axarr[4].imshow(core[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[4].title.set_text(f'{SEGMENT_CLASSES[2]} predicted')
    axarr[5].imshow(enhancing[start_slice,:,], cmap="OrRd", interpolation='none', alpha=0.3)
    axarr[5].title.set_text(f'{SEGMENT_CLASSES[3]} predicted')
    plt.show()

# %%
showPredictsById(case=test_ids[0][-3:])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
showPredictsById(case=test_ids[1][-3:])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
showPredictsById(case=test_ids[2][-3:])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %%
showPredictsById(case=test_ids[3][-3:])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
showPredictsById(case=test_ids[4][-3:])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
showPredictsById(case=test_ids[5][-3:])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
showPredictsById(case=test_ids[6][-3:])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
def predict_segmentation(sample_path):
    # Load NIfTI (.nii) files of the sample (patient)
    t1ce_path = sample_path + '_t1ce.nii'
    flair_path = sample_path + '_flair.nii'

    # Extract the data from these paths
    t1ce = nib.load(t1ce_path).get_fdata()
    flair = nib.load(flair_path).get_fdata()

    # Create an empty array
    X = np.empty((VOLUME_SLICES, IMG_SIZE, IMG_SIZE, 2))

    # Perform the same operations as our DataGenerator, to keep the same input shape
    for j in range(VOLUME_SLICES):
        X[j,:,:,0] = cv2.resize(flair[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))
        X[j,:,:,1] = cv2.resize(t1ce[:,:,j+VOLUME_START_AT], (IMG_SIZE,IMG_SIZE))

    # Send our images to the CNN model and return predicted segmentation
    return model.predict(X/np.max(X), verbose=1)

# %%
def show_predicted_segmentations(samples_list, slice_to_plot, cmap, norm):
    # Choose a random patient
    random_sample = random.choice(samples_list)

    # Get path of this patient
    random_sample_path = os.path.join(TRAIN_DATASET_PATH, random_sample, random_sample)

    # Predict patient's segmentation
    predicted_seg = predict_segmentation(random_sample_path)

    # Load patient's original segmentation (Ground truth)
    seg_path = random_sample_path + '_seg.nii'
    seg = nib.load(seg_path).get_fdata()

    # Resize original segmentation to the same dimensions of the predictions. (Add VOLUME_START_AT because original segmentation contains 155 slices vs only 75 for our prediction)
    seg=cv2.resize(seg[:,:,slice_to_plot+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE), interpolation = cv2.INTER_NEAREST)

    # Differentiate segmentations by their labels
    all = predicted_seg[slice_to_plot,:,:,1:4] # Deletion of class 0 (Keep only Core + Edema + Enhancing classes)
    zero = predicted_seg[slice_to_plot,:,:,0] # Isolation of class 0, Background (kind of useless, it is the opposite of the "all")
    first = predicted_seg[slice_to_plot,:,:,1] # Isolation of class 1, Core
    second = predicted_seg[slice_to_plot,:,:,2] # Isolation of class 2, Edema
    third = predicted_seg[slice_to_plot,:,:,3] # Isolation of class 3, Enhancing

    # Plot Original segmentation & predicted segmentation
    print("Patient number: ", random_sample)
    fig, axstest = plt.subplots(1, 6, figsize=(25, 20))

    # Original segmentation
    axstest[0].imshow(seg, cmap, norm)
    axstest[0].set_title('Original Segmentation')

    # Layers 1, 2, 3
    axstest[1].imshow(all, cmap, norm)
    axstest[1].set_title('Predicted Segmentation - all classes')

    # Layer 0
    axstest[2].imshow(zero)
    axstest[2].set_title('Predicted Segmentation - Not Tumor')

    # Layer 1
    axstest[3].imshow(first)
    axstest[3].set_title('Predicted Segmentation - Necrotic/Core')

    # Layer 2
    axstest[4].imshow(second)
    axstest[4].set_title('Predicted Segmentation - Edema')

    # Layer 3
    axstest[5].imshow(third)
    axstest[5].set_title('Predicted Segmentation - Enhancing')

    # Add space between subplots
    plt.subplots_adjust(wspace=0.8)

    plt.show()

# %%
show_predicted_segmentations(test_ids, 30, cmap, norm)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Patient number:  BraTS20_Training_252

# %%
show_predicted_segmentations(test_ids, 30, cmap, norm)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Patient number:  BraTS20_Training_087

# %%
show_predicted_segmentations(test_ids, 35, cmap, norm)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Patient number:  BraTS20_Training_133

# %%
case = test_ids[3][-3:]
path = f"BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData/BraTS20_Training_{case}"
gt = nib.load(os.path.join(path, f'BraTS20_Training_{case}_seg.nii')).get_fdata()
p = predictByPath(path,case)

core = p[:,:,:,1]
edema= p[:,:,:,2]
enhancing = p[:,:,:,3]

i=20 # slice at
eval_class = 2 #     0 : 'NOT tumor',  1 : 'ENHANCING',    2 : 'CORE',    3 : 'WHOLE'

gt[gt != eval_class] = 1 # use only one class for per class evaluation

resized_gt = cv2.resize(gt[:,:,i+VOLUME_START_AT], (IMG_SIZE, IMG_SIZE))

plt.figure()
f, axarr = plt.subplots(1,2)
axarr[0].imshow(resized_gt, cmap="gray")
axarr[0].title.set_text('ground truth')
axarr[1].imshow(p[i,:,:,eval_class], cmap="gray")
axarr[1].title.set_text(f'predicted class: {SEGMENT_CLASSES[eval_class]}')
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
# Evaluate the model on the test data
model.compile(loss="categorical_crossentropy",
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics = ['accuracy',tf.keras.metrics.MeanIoU(num_classes=4), dice_coef, precision, sensitivity, specificity, dice_coef_necrotic, dice_coef_edema, dice_coef_enhancing])

results = model.evaluate(test_generator, batch_size=100, callbacks= callbacks)

descriptions = ["Loss", "Accuracy", "MeanIOU", "Dice coefficient", "Precision", "Sensitivity", "Specificity", "Dice coef Necrotic", "Dice coef Edema", "Dice coef Enhancing"]

# Combine results list and descriptions list
results_list = zip(results, descriptions)

# Display each metric with its description
print("\nModel evaluation on the test set:")
print("==================================")
for i, (metric, description) in enumerate(results_list):
    print(f"{description} : {round(metric, 4)}")
# Out:
# /home/sandeep/Documents/clg-sem-6/dip-project/venv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 114ms/step - accuracy: 0.9849 - dice_coef: 0.5375 - dice_coef_edema: 0.6428 - dice_coef_enhancing: 0.5413 - dice_coef_necrotic: 0.4045 - loss: 0.0498 - mean_io_u_3: 0.6297 - precision: 0.9864 - sensitivity: 0.9824 - specificity: 0.9954
#
# Model evaluation on the test set:
# ==================================
# Loss : 0.0498
# Accuracy : 0.9849
# MeanIOU : 0.6297
# Dice coefficient : 0.5375
# Precision : 0.9864
# Sensitivity : 0.9824
# Specificity : 0.9954
# Dice coef Necrotic : 0.4045
# Dice coef Edema : 0.6428
# Dice coef Enhancing : 0.5413
